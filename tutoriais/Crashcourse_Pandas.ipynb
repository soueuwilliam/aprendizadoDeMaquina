# %% [markdown]
# <a href="https://colab.research.google.com/github/soueuwilliam/aprendizadoDeMaquina/blob/main/tutoriais/Crashcourse_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introdução
#
#  A biblioteca [Pandas](https://pandas.pydata.org/docs/index.html) é uma ferramenta de análise e manipulação de dados em Python. Ela oferece estruturas de dados poderosas e flexíveis para facilitar o trabalho com dados tabulares e séries temporais.
#
# Graças à sua sintaxe simples e eficiente, o Pandas é amplamente utilizado em ciência de dados, análise financeira, bioinformática, engenharia e muitas outras áreas onde o trabalho com dados é essencial.
#
# O pandas fornece dois tipos de classes para gerenciamento de dados:
#
# - Series: uma matriz unidimensional rotulada contendo dados de qualquer tipo
# como inteiros, strings, objetos Python etc.
# - DataFrame: uma estrutura de dados bidimensional que contém dados como uma matriz bidimensional ou uma tabela com linhas e colunas.
#
# O DataFrame, que é essencialmente uma tabela bidimensional com linhas e colunas rotuladas, permite que você realize operações de forma eficiente em grandes conjuntos de dados, incluindo seleção, filtragem, agregação, limpeza, transformação e visualização de dados.
#
# Vale dizer que o Pandas é construído sobre o [NumPy](https://numpy.org/) e estende suas funcionalidades, fornecendo estruturas de dados de alto nível e ferramentas para análise de dados. Então, ao trabalhar com dados, muitas vezes você usará tanto Pandas quanto NumPy juntos, aproveitando as vantagens de ambas as bibliotecas para análise e manipulação de dados.
#
# Além disso, o Pandas possui integração direta com [Matplotlib](https://matplotlib.org/), o que facilita a visualização de dados armazenados em estruturas de dados do Pandas.
#
# Dessa forma, o Pandas fornece métodos convenientes para criar gráficos diretamente a partir de objetos DataFrame e Series usando Matplotlib. Isso simplifica o processo de criação de visualizações a partir de dados Pandas, eliminando a necessidade de escrever código adicional para preparar os dados para plotagem.

# %% [markdown]
# # Importar o Pandas
#
# Para utilizar os recursos do Pandas é necessário realizar a importação. Em geral, para facilitar, é adicionado um _alias_ no pacote.
#
# Vamos aproveitar também para importar o Numpy e o Matplotlib, também usando um _alias_.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Criando DataFrames
#
# Existem algumas maneiras para criar um DataFrame no Pandas. Além da ideia de utilizar Nympy arrays ou Series para preencher um DataFrame, vamos ver algumas outras maneiras nas próximas seções.

# %% [markdown]
# ## Lista de Dicionários
#
# A partir de uma lista de dicionários, conseguimos preencher um DataFrame por linhas, em que cada entrada da lista se transforma em uma nova linha do DataFrame.

# %%
list_of_dicts = [
    {"name": "Ginger", "breed": "Dachshund", "height_cm": 22, "weight_kg": 10, "date_of_birth": "2019-03-14"},
    {"name": "Scout", "breed": "Dalmatian", "height_cm": 59, "weight_kg": 25, "date_of_birth": "2019-05-09"}
    ]
df = pd.DataFrame(list_of_dicts)
df
# Out:
#      name      breed  height_cm  weight_kg date_of_birth
# 0  Ginger  Dachshund         22         10    2019-03-14
# 1   Scout  Dalmatian         59         25    2019-05-09

# %% [markdown]
# ## Dicionário de listas
#
# Uma outra abordagem é preencher o DataFrame coluna por coluna. Para isso, podemos utilizar um dicionário de listas.

# %%
dict_of_lists = {
    "name": ["Ginger", "Scout"],
    "breed": ["Dachshund", "Dalmatian"],
    "height_cm": [22, 59],
    "weight_kg": [10, 25],
    "date_of_birth": ["2019-03-14", "2019-05-09"]
    }
df = pd.DataFrame(dict_of_lists)
df
# Out:
#      name      breed  height_cm  weight_kg date_of_birth
# 0  Ginger  Dachshund         22         10    2019-03-14
# 1   Scout  Dalmatian         59         25    2019-05-09

# %% [markdown]
# # Importando e exportando dados
#
# Em muitas situações (talvez, a maioria), os dados a serem analisados estão armazenados em fontes externas. O Pandas possui um amplo conjunto de métodos para fazer a leitura e escrita de arquivos em formatos específicos. Uma lista completa dos formatos pode ser vista [aqui](https://pandas.pydata.org/docs/user_guide/io.html).
#
# Para fins de exemplificação, vamos trabalhar com um formato bastante comum, o CSV.

# %% [markdown]
# Para a maior parte deste Notebooke, vamos usar uma base de dados com informações sobre salário para cargos na área de Ciência de Dados. Os dados foram coletados nesse [repostório no Kaggle](https://www.kaggle.com/datasets/ruchi798/data-science-job-salaries).
#
# Primeiro, vamos trazer para o ambiente do Google Colab um conjunto de dados.

# %%
# !wget https://raw.githubusercontent.com/danielsabino/IMD1101-AM-2024.1/pandas/ds_salaries.csv
# Out:
# --2024-03-19 23:51:38--  https://raw.githubusercontent.com/danielsabino/IMD1101-AM-2024.1/pandas/ds_salaries.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 36961 (36K) [text/plain]
# Saving to: ‘ds_salaries.csv’
#
# ds_salaries.csv     100%[===================>]  36.09K  --.-KB/s    in 0.004s
#
# 2024-03-19 23:51:39 (9.77 MB/s) - ‘ds_salaries.csv’ saved [36961/36961]

# %% [markdown]
# Agora, para fazer preencher um DataFrame com os referidos dados, basta usar o método `.read_csv()`.

# %%
df = pd.read_csv('ds_salaries.csv')

# %% [markdown]
# De maneira semalhante, se quisermos salvar o conteúdo de DataFrame em um arquivo CSV, basta usar o método `.to_csv()`.

# %%
df.to_csv('arquivo.csv')

# %% [markdown]
# # Métodos e atributos básicos
#
# Assim que uma base de dados é carregada, a primeira coisa a fazer é explorar e verificar o que contém nela. Alguns métodos podem ser usados para obter algumas informações úteis:
#
# - `head()`: retorna as primeiras linhas da dataframe - bom para ver exemplos de valores que estão armazenados;
# - `tail()`: retorna as últimas linhas da dataframe - bom para ver exemplos de valores que estão armazenados;
# - `info()`: mostra informações para cada coluna, como o tipo de cada uma delas e a quantidade de valores faltosos;
# - `describe()`: traz algumas estatísticas básicas para cada coluna;
# - `shape`: mostra a quantidade de linhas e colunas do dataframe.

# %%
df.head()
# Out:
#    id  work_year experience_level employment_type                   job_title  \
# 0   0       2020               MI              FT              Data Scientist
# 1   1       2020               SE              FT  Machine Learning Scientist
# 2   2       2020               SE              FT           Big Data Engineer
# 3   3       2020               MI              FT        Product Data Analyst
# 4   4       2020               SE              FT   Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   70000             EUR          79833                 DE             0
# 1  260000             USD         260000                 JP             0
# 2   85000             GBP         109024                 GB            50
# 3   20000             USD          20000                 HN             0
# 4  150000             USD         150000                 US            50
#
#   company_location company_size
# 0               DE            L
# 1               JP            S
# 2               GB            M
# 3               HN            S
# 4               US            L

# %%
df.tail()
# Out:
#       id  work_year experience_level employment_type      job_title  salary  \
# 602  602       2022               SE              FT  Data Engineer  154000
# 603  603       2022               SE              FT  Data Engineer  126000
# 604  604       2022               SE              FT   Data Analyst  129000
# 605  605       2022               SE              FT   Data Analyst  150000
# 606  606       2022               MI              FT   AI Scientist  200000
#
#     salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 602             USD         154000                 US           100
# 603             USD         126000                 US           100
# 604             USD         129000                 US             0
# 605             USD         150000                 US           100
# 606             USD         200000                 IN           100
#
#     company_location company_size
# 602               US            M
# 603               US            M
# 604               US            M
# 605               US            M
# 606               US            L

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  607 non-null    int64
#  1   work_year           607 non-null    int64
#  2   experience_level    607 non-null    object
#  3   employment_type     607 non-null    object
#  4   job_title           607 non-null    object
#  5   salary              607 non-null    int64
#  6   salary_currency     607 non-null    object
#  7   salary_in_usd       607 non-null    int64
#  8   employee_residence  607 non-null    object
#  9   remote_ratio        607 non-null    int64
#  10  company_location    607 non-null    object
#  11  company_size        607 non-null    object
# dtypes: int64(5), object(7)
# memory usage: 57.0+ KB

# %%
df.describe()
# Out:
#                id    work_year        salary  salary_in_usd  remote_ratio
# count  607.000000   607.000000  6.070000e+02     607.000000     607.00000
# mean   303.000000  2021.405272  3.240001e+05  112297.869852      70.92257
# std    175.370085     0.692133  1.544357e+06   70957.259411      40.70913
# min      0.000000  2020.000000  4.000000e+03    2859.000000       0.00000
# 25%    151.500000  2021.000000  7.000000e+04   62726.000000      50.00000
# 50%    303.000000  2022.000000  1.150000e+05  101570.000000     100.00000
# 75%    454.500000  2022.000000  1.650000e+05  150000.000000     100.00000
# max    606.000000  2022.000000  3.040000e+07  600000.000000     100.00000

# %%
df.shape
# Out:
# (607, 12)

# %% [markdown]
# # Estrutura de um DataFrame
#
# Para melhor entender um objeto do tipo DataFrame, é importante entender que eles são compostos de três componentes básicos, que podem ser acessados por meio dos seguintes atributos:
#
# - `values`: um array NumPy bidimensional com os valores armazenados no DataFrame;
# - `columns`: um índice com os nomes das colunas;
# - `index`: um índice para as linhas - podem ser números ou nomes.
#
# PS: um índice é um tipo de dados do Pandas (`index`), que pode ser enxergado como uma lista de strings ou números.

# %%
df.values
# Out:
# array([[0, 2020, 'MI', ..., 0, 'DE', 'L'],
#        [1, 2020, 'SE', ..., 0, 'JP', 'S'],
#        [2, 2020, 'SE', ..., 50, 'GB', 'M'],
#        ...,
#        [604, 2022, 'SE', ..., 0, 'US', 'M'],
#        [605, 2022, 'SE', ..., 100, 'US', 'M'],
#        [606, 2022, 'MI', ..., 100, 'US', 'L']], dtype=object)

# %%
df.columns
# Out:
# Index(['id', 'work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=607, step=1)

# %% [markdown]
# # Ordenando e selecionando

# %% [markdown]
# ## Ordenando linhas
#
# Um opção interessante para analisar os dados é realizar a ordenação a partir de uma coluna específica. Para isso, podemos usar o método `sort_values()`.

# %%
df.sort_values('work_year')
# Out:
#       id  work_year experience_level employment_type  \
# 0      0       2020               MI              FT
# 51    51       2020               EN              FT
# 50    50       2020               EN              FT
# 49    49       2020               MI              FT
# 48    48       2020               MI              FT
# ..   ...        ...              ...             ...
# 391  391       2022               MI              FT
# 390  390       2022               MI              FT
# 389  389       2022               MI              FT
# 396  396       2022               MI              FT
# 606  606       2022               MI              FT
#
#                      job_title  salary salary_currency  salary_in_usd  \
# 0               Data Scientist   70000             EUR          79833
# 51                Data Analyst   91000             USD          91000
# 50                Data Analyst  450000             INR           6072
# 49               Data Engineer   61500             EUR          70139
# 48              Data Scientist  105000             USD         105000
# ..                         ...     ...             ...            ...
# 391               AI Scientist  120000             USD         120000
# 390  Machine Learning Engineer   75000             GBP          98158
# 389  Machine Learning Engineer   95000             GBP         124333
# 396  Machine Learning Engineer   80000             EUR          87932
# 606               AI Scientist  200000             USD         200000
#
#     employee_residence  remote_ratio company_location company_size
# 0                   DE             0               DE            L
# 51                  US           100               US            L
# 50                  IN             0               IN            S
# 49                  FR            50               FR            L
# 48                  US           100               US            L
# ..                 ...           ...              ...          ...
# 391                 US             0               US            M
# 390                 GB             0               GB            M
# 389                 GB             0               GB            M
# 396                 FR           100               DE            M
# 606                 IN           100               US            L
#
# [607 rows x 12 columns]

# %% [markdown]
#  Você pode configurar o parâmetro `ascending` para indicar se quer o dado ordenado de forma crescente ou descrescente.

# %%
df.sort_values('salary', ascending=False)
# Out:
#       id  work_year experience_level employment_type        job_title  \
# 177  177       2021               MI              FT   Data Scientist
# 7      7       2020               MI              FT   Data Scientist
# 102  102       2021               MI              FT  BI Data Analyst
# 137  137       2021               MI              FT      ML Engineer
# 136  136       2021               MI              FT      ML Engineer
# ..   ...        ...              ...             ...              ...
# 196  196       2021               EN              FT  BI Data Analyst
# 124  124       2021               EN              PT     Data Analyst
# 15    15       2020               MI              FT     Data Analyst
# 185  185       2021               MI              FT    Data Engineer
# 238  238       2021               EN              FT   Data Scientist
#
#        salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 177  30400000             CLP          40038                 CL           100
# 7    11000000             HUF          35735                 HU            50
# 102  11000000             HUF          36259                 HU            50
# 137   8500000             JPY          77364                 JP            50
# 136   7000000             JPY          63711                 JP            50
# ..        ...             ...            ...                ...           ...
# 196      9272             USD           9272                 KE           100
# 124      8760             EUR          10354                 ES            50
# 15       8000             USD           8000                 PK            50
# 185      4000             USD           4000                 IR           100
# 238      4000             USD           4000                 VN             0
#
#     company_location company_size
# 177               CL            L
# 7                 HU            L
# 102               US            L
# 137               JP            S
# 136               JP            S
# ..               ...          ...
# 196               KE            S
# 124               ES            M
# 15                PK            L
# 185               IR            M
# 238               VN            M
#
# [607 rows x 12 columns]

# %% [markdown]
# Também é possível passar uma lista de colunas para fazer uma ordenação múltipla (de acordo com a ordem informada na lista). A extensão também é válida para o parâmetro de ordenação.

# %%
df.sort_values(['salary', 'experience_level'], ascending=[False, True])
# Out:
#       id  work_year experience_level employment_type        job_title  \
# 177  177       2021               MI              FT   Data Scientist
# 7      7       2020               MI              FT   Data Scientist
# 102  102       2021               MI              FT  BI Data Analyst
# 137  137       2021               MI              FT      ML Engineer
# 136  136       2021               MI              FT      ML Engineer
# ..   ...        ...              ...             ...              ...
# 196  196       2021               EN              FT  BI Data Analyst
# 124  124       2021               EN              PT     Data Analyst
# 15    15       2020               MI              FT     Data Analyst
# 238  238       2021               EN              FT   Data Scientist
# 185  185       2021               MI              FT    Data Engineer
#
#        salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 177  30400000             CLP          40038                 CL           100
# 7    11000000             HUF          35735                 HU            50
# 102  11000000             HUF          36259                 HU            50
# 137   8500000             JPY          77364                 JP            50
# 136   7000000             JPY          63711                 JP            50
# ..        ...             ...            ...                ...           ...
# 196      9272             USD           9272                 KE           100
# 124      8760             EUR          10354                 ES            50
# 15       8000             USD           8000                 PK            50
# 238      4000             USD           4000                 VN             0
# 185      4000             USD           4000                 IR           100
#
#     company_location company_size
# 177               CL            L
# 7                 HU            L
# 102               US            L
# 137               JP            S
# 136               JP            S
# ..               ...          ...
# 196               KE            S
# 124               ES            M
# 15                PK            L
# 238               VN            M
# 185               IR            M
#
# [607 rows x 12 columns]

# %% [markdown]
# ## Selecionando colunas
#
# As vezes, pode ser útil focar em uma única coluna do conjunto de dados. Com o Pandas, é fácil fazer isso. Basta utilizar o operador de seleção `[]` informando uma lista de colunas que se deseja mostrar.

# %%
df['employee_residence']
# Out:
# 0      DE
# 1      JP
# 2      GB
# 3      HN
# 4      US
#        ..
# 602    US
# 603    US
# 604    US
# 605    US
# 606    IN
# Name: employee_residence, Length: 607, dtype: object

# %%
df[['employee_residence','company_location']]
# Out:
#     employee_residence company_location
# 0                   DE               DE
# 1                   JP               JP
# 2                   GB               GB
# 3                   HN               HN
# 4                   US               US
# ..                 ...              ...
# 602                 US               US
# 603                 US               US
# 604                 US               US
# 605                 US               US
# 606                 IN               US
#
# [607 rows x 2 columns]

# %% [markdown]
# ## Selecionando linhas
#
# Da mesma forma que podemos selecionar colunas, podemos também escolher somente algumas linhas para mostrar. Existem múltiplas maneiras de fazer isso.
#
# A primeira é utilizar uma condição específica para obter somente as linhas cuja condição é atendida (a condição pode estar relacionada a uma coluna). Por exemplo, se quisermos obter saber quais cargos possuem salário maior que 100.000, basta fazer o seguinte:

# %%
df['salary'] > 100000
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4       True
#        ...
# 602     True
# 603     True
# 604     True
# 605     True
# 606     True
# Name: salary, Length: 607, dtype: bool

# %% [markdown]
# Usamos o resultado dessa condição dentro como valor de indexação para acessar somente as linhas desejadas.

# %%
df[df['salary'] > 100000]
# Out:
#       id  work_year experience_level employment_type  \
# 1      1       2020               SE              FT
# 4      4       2020               SE              FT
# 6      6       2020               SE              FT
# 7      7       2020               MI              FT
# 8      8       2020               MI              FT
# ..   ...        ...              ...             ...
# 602  602       2022               SE              FT
# 603  603       2022               SE              FT
# 604  604       2022               SE              FT
# 605  605       2022               SE              FT
# 606  606       2022               MI              FT
#
#                       job_title    salary salary_currency  salary_in_usd  \
# 1    Machine Learning Scientist    260000             USD         260000
# 4     Machine Learning Engineer    150000             USD         150000
# 6           Lead Data Scientist    190000             USD         190000
# 7                Data Scientist  11000000             HUF          35735
# 8         Business Data Analyst    135000             USD         135000
# ..                          ...       ...             ...            ...
# 602               Data Engineer    154000             USD         154000
# 603               Data Engineer    126000             USD         126000
# 604                Data Analyst    129000             USD         129000
# 605                Data Analyst    150000             USD         150000
# 606                AI Scientist    200000             USD         200000
#
#     employee_residence  remote_ratio company_location company_size
# 1                   JP             0               JP            S
# 4                   US            50               US            L
# 6                   US           100               US            S
# 7                   HU            50               HU            L
# 8                   US           100               US            L
# ..                 ...           ...              ...          ...
# 602                 US           100               US            M
# 603                 US           100               US            M
# 604                 US             0               US            M
# 605                 US           100               US            M
# 606                 IN           100               US            L
#
# [343 rows x 12 columns]

# %% [markdown]
# As operações podem ser feitas facilmente não só com números mas com outros tipos de dados, como strings e datas.

# %%
df[df['company_size'] == 'L']
# Out:
#       id  work_year experience_level employment_type  \
# 0      0       2020               MI              FT
# 4      4       2020               SE              FT
# 5      5       2020               EN              FT
# 7      7       2020               MI              FT
# 8      8       2020               MI              FT
# ..   ...        ...              ...             ...
# 524  524       2022               MI              FT
# 525  525       2022               SE              FT
# 550  550       2022               SE              FT
# 551  551       2022               SE              FT
# 606  606       2022               MI              FT
#
#                      job_title    salary salary_currency  salary_in_usd  \
# 0               Data Scientist     70000             EUR          79833
# 4    Machine Learning Engineer    150000             USD         150000
# 5                 Data Analyst     72000             USD          72000
# 7               Data Scientist  11000000             HUF          35735
# 8        Business Data Analyst    135000             USD         135000
# ..                         ...       ...             ...            ...
# 524             Data Scientist    135000             USD         135000
# 525     Applied Data Scientist    177000             USD         177000
# 550             Data Scientist    205300             USD         205300
# 551             Data Scientist    140400             USD         140400
# 606               AI Scientist    200000             USD         200000
#
#     employee_residence  remote_ratio company_location company_size
# 0                   DE             0               DE            L
# 4                   US            50               US            L
# 5                   US           100               US            L
# 7                   HU            50               HU            L
# 8                   US           100               US            L
# ..                 ...           ...              ...          ...
# 524                 US           100               US            L
# 525                 US           100               US            L
# 550                 US             0               US            L
# 551                 US             0               US            L
# 606                 IN           100               US            L
#
# [198 rows x 12 columns]

# %% [markdown]
# A seleção baseada em múltiplas condições deve ser acompanhada de operadores lógicos. Os operadores mais comuns são:
#
# `&`: operador and;
# `|`: operador or;
# `~`: operador not.
#
# Para facilitar a leitura, podemos atribuir as condições à variáveis específicas de forma separadas e utilizar essas variáveis como índices para seleção.

# %%
data_scientists = df['job_title'] == 'Data Scientist'
good_salaries = df['salary'] > 100000
df[data_scientists & good_salaries]
# Out:
#       id  work_year experience_level employment_type       job_title  \
# 7      7       2020               MI              FT  Data Scientist
# 11    11       2020               MI              FT  Data Scientist
# 48    48       2020               MI              FT  Data Scientist
# 57    57       2020               MI              FT  Data Scientist
# 58    58       2020               SE              FT  Data Scientist
# ..   ...        ...              ...             ...             ...
# 592  592       2022               SE              FT  Data Scientist
# 593  593       2022               SE              FT  Data Scientist
# 596  596       2022               SE              FT  Data Scientist
# 598  598       2022               MI              FT  Data Scientist
# 599  599       2022               MI              FT  Data Scientist
#
#        salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 7    11000000             HUF          35735                 HU            50
# 11    3000000             INR          40481                 IN             0
# 48     105000             USD         105000                 US           100
# 57     118000             USD         118000                 US           100
# 58     120000             USD         120000                 US            50
# ..        ...             ...            ...                ...           ...
# 592    230000             USD         230000                 US           100
# 593    150000             USD         150000                 US           100
# 596    210000             USD         210000                 US           100
# 598    160000             USD         160000                 US           100
# 599    130000             USD         130000                 US           100
#
#     company_location company_size
# 7                 HU            L
# 11                IN            L
# 48                US            L
# 57                US            M
# 58                US            L
# ..               ...          ...
# 592               US            M
# 593               US            M
# 596               US            M
# 598               US            M
# 599               US            M
#
# [85 rows x 12 columns]

# %% [markdown]
# Se for agregar todo o código em uma só linha, o opreador de parênteses deve ser usado para separar as condições

# %%
df[(df['job_title'] == 'Data Scientist') & (df['salary'] > 100000)]
# Out:
#       id  work_year experience_level employment_type       job_title  \
# 7      7       2020               MI              FT  Data Scientist
# 11    11       2020               MI              FT  Data Scientist
# 48    48       2020               MI              FT  Data Scientist
# 57    57       2020               MI              FT  Data Scientist
# 58    58       2020               SE              FT  Data Scientist
# ..   ...        ...              ...             ...             ...
# 592  592       2022               SE              FT  Data Scientist
# 593  593       2022               SE              FT  Data Scientist
# 596  596       2022               SE              FT  Data Scientist
# 598  598       2022               MI              FT  Data Scientist
# 599  599       2022               MI              FT  Data Scientist
#
#        salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 7    11000000             HUF          35735                 HU            50
# 11    3000000             INR          40481                 IN             0
# 48     105000             USD         105000                 US           100
# 57     118000             USD         118000                 US           100
# 58     120000             USD         120000                 US            50
# ..        ...             ...            ...                ...           ...
# 592    230000             USD         230000                 US           100
# 593    150000             USD         150000                 US           100
# 596    210000             USD         210000                 US           100
# 598    160000             USD         160000                 US           100
# 599    130000             USD         130000                 US           100
#
#     company_location company_size
# 7                 HU            L
# 11                IN            L
# 48                US            L
# 57                US            M
# 58                US            L
# ..               ...          ...
# 592               US            M
# 593               US            M
# 596               US            M
# 598               US            M
# 599               US            M
#
# [85 rows x 12 columns]

# %% [markdown]
# Para colunas do tipo categórico, é possível utilizar o método `isin()` informando uma lista de valores.

# %%
df[df['salary_currency'].isin(['BRL','GBP'])]
# Out:
#       id  work_year experience_level employment_type  \
# 2      2       2020               SE              FT
# 44    44       2020               MI              FT
# 46    46       2020               MI              FT
# 72    72       2021               EN              FT
# 105  105       2021               MI              FT
# 111  111       2021               SE              FT
# 112  112       2021               SE              FT
# 123  123       2021               EN              FT
# 171  171       2021               MI              FT
# 183  183       2021               SE              FT
# 205  205       2021               MI              FT
# 212  212       2021               MI              FT
# 221  221       2021               MI              FT
# 223  223       2021               MI              FT
# 245  245       2021               MI              FT
# 248  248       2021               SE              FT
# 271  271       2021               SE              FT
# 300  300       2022               SE              FT
# 301  301       2022               SE              FT
# 304  304       2022               EN              FT
# 311  311       2022               MI              FT
# 312  312       2022               MI              FT
# 313  313       2022               MI              FT
# 314  314       2022               MI              FT
# 316  316       2022               EN              FT
# 354  354       2022               SE              FT
# 355  355       2022               SE              FT
# 386  386       2022               EN              FT
# 389  389       2022               MI              FT
# 390  390       2022               MI              FT
# 397  397       2022               MI              FT
# 405  405       2022               MI              FT
# 408  408       2022               MI              FT
# 410  410       2022               MI              FT
# 411  411       2022               MI              FT
# 414  414       2022               MI              FT
# 415  415       2022               MI              FT
# 429  429       2022               MI              FT
# 434  434       2022               MI              FT
# 435  435       2022               MI              FT
# 442  442       2022               MI              FT
# 443  443       2022               MI              FT
# 474  474       2022               MI              FT
# 475  475       2022               MI              FT
# 567  567       2022               MI              FT
# 586  586       2022               MI              FT
#
#                         job_title  salary salary_currency  salary_in_usd  \
# 2               Big Data Engineer   85000             GBP         109024
# 44                  Data Engineer   88000             GBP         112872
# 46                 Data Scientist   60000             GBP          76958
# 72             Research Scientist   60000             GBP          82528
# 105                  Data Analyst   37456             GBP          51519
# 111  Director of Data Engineering   82500             GBP         113476
# 112            Lead Data Engineer   75000             GBP         103160
# 123        Applied Data Scientist   80000             GBP         110037
# 171                 Data Engineer   60000             GBP          82528
# 183          Finance Data Analyst   45000             GBP          61896
# 205                Data Scientist   69600             BRL          12901
# 212                 Data Engineer   48000             GBP          66022
# 221                Data Scientist   85000             GBP         116914
# 223                Data Scientist   40900             GBP          56256
# 245                 Data Engineer   52500             GBP          72212
# 248                 Data Engineer   70000             GBP          96282
# 271      Computer Vision Engineer  102000             BRL          18907
# 300                Data Scientist   90000             GBP         117789
# 301                Data Scientist   80000             GBP         104702
# 304                 Data Engineer   40000             GBP          52351
# 311                Data Scientist   50000             GBP          65438
# 312                Data Scientist   30000             GBP          39263
# 313                 Data Engineer   60000             GBP          78526
# 314                 Data Engineer   40000             GBP          52351
# 316                 Data Engineer   35000             GBP          45807
# 354                 Data Engineer   60000             GBP          78526
# 355                 Data Engineer   50000             GBP          65438
# 386     Machine Learning Engineer   28500             GBP          37300
# 389     Machine Learning Engineer   95000             GBP         124333
# 390     Machine Learning Engineer   75000             GBP          98158
# 397                 Data Engineer   90000             GBP         117789
# 405                 Data Engineer   75000             GBP          98158
# 408                  Data Analyst   40000             GBP          52351
# 410                Data Scientist   55000             GBP          71982
# 411                Data Scientist   35000             GBP          45807
# 414                 Data Engineer   60000             GBP          78526
# 415                 Data Engineer   45000             GBP          58894
# 429                  Data Analyst   30000             GBP          39263
# 434                 Data Engineer   80000             GBP         104702
# 435                 Data Engineer   70000             GBP          91614
# 442                 Data Engineer   75000             GBP          98158
# 443                 Data Engineer   60000             GBP          78526
# 474                Data Scientist  140000             GBP         183228
# 475                Data Scientist   70000             GBP          91614
# 567                  Data Analyst   50000             GBP          65438
# 586                  Data Analyst   35000             GBP          45807
#
#     employee_residence  remote_ratio company_location company_size
# 2                   GB            50               GB            M
# 44                  GB            50               GB            L
# 46                  GB           100               GB            S
# 72                  GB            50               GB            L
# 105                 GB            50               GB            L
# 111                 GB           100               GB            M
# 112                 GB           100               GB            S
# 123                 GB             0               GB            L
# 171                 GB           100               GB            L
# 183                 GB            50               GB            L
# 205                 BR             0               BR            S
# 212                 HK            50               GB            S
# 221                 GB            50               GB            L
# 223                 GB            50               GB            L
# 245                 GB            50               GB            L
# 248                 GB            50               GB            L
# 271                 BR             0               BR            M
# 300                 GB             0               GB            M
# 301                 GB             0               GB            M
# 304                 GB           100               GB            M
# 311                 GB             0               GB            M
# 312                 GB             0               GB            M
# 313                 GB             0               GB            M
# 314                 GB             0               GB            M
# 316                 GB           100               GB            M
# 354                 GB             0               GB            M
# 355                 GB             0               GB            M
# 386                 GB           100               GB            L
# 389                 GB             0               GB            M
# 390                 GB             0               GB            M
# 397                 GB             0               GB            M
# 405                 GB             0               GB            M
# 408                 GB           100               GB            M
# 410                 GB             0               GB            M
# 411                 GB             0               GB            M
# 414                 GB           100               GB            M
# 415                 GB           100               GB            M
# 429                 GB           100               GB            M
# 434                 GB           100               GB            M
# 435                 GB           100               GB            M
# 442                 GB           100               GB            M
# 443                 GB           100               GB            M
# 474                 GB             0               GB            M
# 475                 GB             0               GB            M
# 567                 GB             0               GB            M
# 586                 GB             0               GB            M

# %% [markdown]
# # Adicionando colunas
#
# Para criar uma nova coluna no DataFrame, basta fazer uma referência dentro do operador `[]` atribuindo valores.
#
# Vamos supor que desejamos adicionar uma coluna de salário mensal no nosso dataset.

# %%
df['montly_salary'] = df['salary_in_usd'] / 12
df.head()
# Out:
#    id  work_year experience_level employment_type                   job_title  \
# 0   0       2020               MI              FT              Data Scientist
# 1   1       2020               SE              FT  Machine Learning Scientist
# 2   2       2020               SE              FT           Big Data Engineer
# 3   3       2020               MI              FT        Product Data Analyst
# 4   4       2020               SE              FT   Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   70000             EUR          79833                 DE             0
# 1  260000             USD         260000                 JP             0
# 2   85000             GBP         109024                 GB            50
# 3   20000             USD          20000                 HN             0
# 4  150000             USD         150000                 US            50
#
#   company_location company_size  montly_salary
# 0               DE            L    6652.750000
# 1               JP            S   21666.666667
# 2               GB            M    9085.333333
# 3               HN            S    1666.666667
# 4               US            L   12500.000000

# %% [markdown]
# Podemos combinar as habilidades de ordenar, selecionar linhas e colunas, e adicionar novas colunas.
#
# Por exemplo, se quisermos responder a pergunta: qual os melhores valores de hora de trabalho o cargo de Cientista de Dados que trabalha em uma empresa dos Estados Unidos?
#
# PS: vamos considerar 160 horas de trabalho por mês para fins de exemplificação.

# %%
df_ds_usa = df[(df['job_title'] == 'Data Scientist') & (df['company_location'] == 'US')]
df_ds_usa['hour_value'] = df_ds_usa['montly_salary'] / 160
df_ds_usa.sort_values('hour_value', ascending=False).head()
# Out:
# <ipython-input-27-80b2661d5025>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ds_usa['hour_value'] = df_ds_usa['montly_salary'] / 160
#       id  work_year experience_level employment_type       job_title  salary  \
# 63    63       2020               SE              FT  Data Scientist  412000
# 416  416       2022               SE              FT  Data Scientist  260000
# 486  486       2022               SE              FT  Data Scientist  230000
# 592  592       2022               SE              FT  Data Scientist  230000
# 472  472       2022               SE              FT  Data Scientist  220000
#
#     salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 63              USD         412000                 US           100
# 416             USD         260000                 US           100
# 486             USD         230000                 US           100
# 592             USD         230000                 US           100
# 472             USD         220000                 US           100
#
#     company_location company_size  montly_salary  hour_value
# 63                US            L   34333.333333  214.583333
# 416               US            M   21666.666667  135.416667
# 486               US            M   19166.666667  119.791667
# 592               US            M   19166.666667  119.791667
# 472               US            M   18333.333333  114.583333

# %% [markdown]
# # Estatísticas sumarizadas
#
# Já usamos o método describe para obter algumas estatísticas sobre os dados. Podemos de forma individual, obter algumas dessas estatísticas também.

# %%
df['salary_in_usd'].mean()
# Out:
# 112297.86985172982

# %%
df['salary_in_usd'].median()
# Out:
# 101570.0

# %%
df['salary_currency'].mode()
# Out:
# 0    USD
# Name: salary_currency, dtype: object

# %%
df['salary_in_usd'].min()
# Out:
# 2859

# %%
df['salary_in_usd'].max()
# Out:
# 600000

# %%
df['salary_in_usd'].var()
# Out:
# 5034932663.176102

# %%
df['salary_in_usd'].std()
# Out:
# 70957.25941139569

# %%
df['salary_in_usd'].quantile(q = 0.4)
# Out:
# 87932.0

# %%
df['salary_in_usd'].cumsum()
# Out:
# 0         79833
# 1        339833
# 2        448857
# 3        468857
# 4        618857
#          ...
# 602    67559807
# 603    67685807
# 604    67814807
# 605    67964807
# 606    68164807
# Name: salary_in_usd, Length: 607, dtype: int64

# %% [markdown]
# A função `agg()` agrega funções definidas pelo usuário para extrair uma ou múltiplas estatísticas ao mesmo tempo.

# %%
# Define o percentil 30 de uma coluna
def pct30(column):
  return column.quantile(0.3)

# Define o percentil 40 de uma coluna
def pct40(column):
  return column.quantile(0.4)

def iqr(column):
  return column.quantile(0.75) - column.quantile(0.25)

# %%
print(df['salary_in_usd'].agg([pct30, pct40]))
# Out:
# pct30    71337.6
# pct40    87932.0
# Name: salary_in_usd, dtype: float64

# %%
print(df[['salary_in_usd','montly_salary']].agg([iqr, np.median]))
# Out:
#         salary_in_usd  montly_salary
# iqr           87274.0    7272.833333
# median       101570.0    8464.166667

# %% [markdown]
# ## Contagem
#
# Para trabalhar com dados categóricos, podemos realizar a contagem de determinados valores de atributos. Para isso, vamos usar o método `value_counts()`.

# %%
df['job_title'].value_counts()
# Out:
# Data Scientist                              143
# Data Engineer                               132
# Data Analyst                                 97
# Machine Learning Engineer                    41
# Research Scientist                           16
# Data Science Manager                         12
# Data Architect                               11
# Big Data Engineer                             8
# Machine Learning Scientist                    8
# Principal Data Scientist                      7
# AI Scientist                                  7
# Data Science Consultant                       7
# Director of Data Science                      7
# Data Analytics Manager                        7
# ML Engineer                                   6
# Computer Vision Engineer                      6
# BI Data Analyst                               6
# Lead Data Engineer                            6
# Data Engineering Manager                      5
# Business Data Analyst                         5
# Head of Data                                  5
# Applied Data Scientist                        5
# Applied Machine Learning Scientist            4
# Head of Data Science                          4
# Analytics Engineer                            4
# Data Analytics Engineer                       4
# Machine Learning Developer                    3
# Machine Learning Infrastructure Engineer      3
# Lead Data Scientist                           3
# Computer Vision Software Engineer             3
# Lead Data Analyst                             3
# Data Science Engineer                         3
# Principal Data Engineer                       3
# Principal Data Analyst                        2
# ETL Developer                                 2
# Product Data Analyst                          2
# Director of Data Engineering                  2
# Financial Data Analyst                        2
# Cloud Data Engineer                           2
# Lead Machine Learning Engineer                1
# NLP Engineer                                  1
# Head of Machine Learning                      1
# 3D Computer Vision Researcher                 1
# Data Specialist                               1
# Staff Data Scientist                          1
# Big Data Architect                            1
# Finance Data Analyst                          1
# Marketing Data Analyst                        1
# Machine Learning Manager                      1
# Data Analytics Lead                           1
# Name: job_title, dtype: int64

# %% [markdown]
# Esse método aceita o parâmetro `normalize` para mostrar a proporção de cada categoria.

# %%
df['job_title'].value_counts(normalize=True)
# Out:
# Data Scientist                              0.235585
# Data Engineer                               0.217463
# Data Analyst                                0.159802
# Machine Learning Engineer                   0.067545
# Research Scientist                          0.026359
# Data Science Manager                        0.019769
# Data Architect                              0.018122
# Big Data Engineer                           0.013180
# Machine Learning Scientist                  0.013180
# Principal Data Scientist                    0.011532
# AI Scientist                                0.011532
# Data Science Consultant                     0.011532
# Director of Data Science                    0.011532
# Data Analytics Manager                      0.011532
# ML Engineer                                 0.009885
# Computer Vision Engineer                    0.009885
# BI Data Analyst                             0.009885
# Lead Data Engineer                          0.009885
# Data Engineering Manager                    0.008237
# Business Data Analyst                       0.008237
# Head of Data                                0.008237
# Applied Data Scientist                      0.008237
# Applied Machine Learning Scientist          0.006590
# Head of Data Science                        0.006590
# Analytics Engineer                          0.006590
# Data Analytics Engineer                     0.006590
# Machine Learning Developer                  0.004942
# Machine Learning Infrastructure Engineer    0.004942
# Lead Data Scientist                         0.004942
# Computer Vision Software Engineer           0.004942
# Lead Data Analyst                           0.004942
# Data Science Engineer                       0.004942
# Principal Data Engineer                     0.004942
# Principal Data Analyst                      0.003295
# ETL Developer                               0.003295
# Product Data Analyst                        0.003295
# Director of Data Engineering                0.003295
# Financial Data Analyst                      0.003295
# Cloud Data Engineer                         0.003295
# Lead Machine Learning Engineer              0.001647
# NLP Engineer                                0.001647
# Head of Machine Learning                    0.001647
# 3D Computer Vision Researcher               0.001647
# Data Specialist                             0.001647
# Staff Data Scientist                        0.001647
# Big Data Architect                          0.001647
# Finance Data Analyst                        0.001647
# Marketing Data Analyst                      0.001647
# Machine Learning Manager                    0.001647
# Data Analytics Lead                         0.001647
# Name: job_title, dtype: float64

# %% [markdown]
# Podemos filtrar o dataset, por exemplo, para considerar somente os 5 cargos com mais pessoas. Sabemos que os cargos são:
# - Data Scientist,
# - Data Engineer,
# - Data Analyst
# - Machine Learning Engineer
# - Research Scientist
#
# Isso pode ser confirmado obtendo os primeiros 5 índices retornados pelo método `.value_counts()`.

# %%
df['job_title'].value_counts().index[:5]
# Out:
# Index(['Data Scientist', 'Data Engineer', 'Data Analyst',
#        'Machine Learning Engineer', 'Research Scientist'],
#       dtype='object')

# %% [markdown]
# Basta, então, filtrar as linhas por cargos que estão nessa lista.

# %%
top5 = df['job_title'].value_counts().index[:5]
df = df[df['job_title'].isin(top5)]

# %% [markdown]
# # Agrupamento
#
# Você pode agrupar estatísticas sobre os porções semelhantes dos dados para ter uma visão mais ampla.
#
# O método `groupby()` agrupa os dados de um atributos cujos valores são iguais.

# %%
df.groupby('job_title')['salary_in_usd']

# %% [markdown]
# O objeto gerado não traz muita informação útil diretamente. Mas, você pode usar esse recurso para calcular algumas estatísticas.
#
# Por exemplo, saber qual a média salarial por cargo.

# %%
df.groupby('job_title')['salary_in_usd'].mean()
# Out:
# job_title
# Data Analyst                  92893.061856
# Data Engineer                112725.000000
# Data Scientist               108187.832168
# Machine Learning Engineer    104880.146341
# Research Scientist           109019.500000
# Name: salary_in_usd, dtype: float64

# %% [markdown]
# Podemos associar esse método com o `agg` para obter múltiplas estatísticas ao mesmo tempo.

# %%
df.groupby('job_title')['salary_in_usd'].agg([np.min,np.max,np.mean,np.median])
# Out:
#                              min     max           mean    median
# job_title
# Data Analyst                6072  200000   92893.061856   90320.0
# Data Engineer               4000  324000  112725.000000  105500.0
# Data Scientist              2859  412000  108187.832168  103691.0
# Machine Learning Engineer  20000  250000  104880.146341   87932.0
# Research Scientist         42000  450000  109019.500000   76263.5

# %% [markdown]
# É possível agrupar por mais de um atributo.

# %%
df.groupby(['job_title', 'experience_level'])['salary_in_usd'].agg([np.min,np.max,np.mean,np.median])
# Out:
#                                                min     max           mean  \
# job_title                 experience_level
# Data Analyst              EN                  6072   91000   53960.666667
#                           EX                110000  130000  120000.000000
#                           MI                  8000  167000   71699.206897
#                           SE                 60000  200000  111922.629630
# Data Engineer             EN                 21637  120000   58933.500000
#                           EX                200000  324000  245500.000000
#                           MI                  4000  206699   85985.660377
#                           SE                 25000  243900  137035.841270
# Data Scientist            EN                  4000  105000   55330.909091
#                           MI                  2859  200000   82039.133333
#                           SE                 20171  412000  152971.016393
# Machine Learning Engineer EN                 20000  250000   86996.333333
#                           MI                 24823  124333   74466.583333
#                           SE                 24342  220000  131176.000000
# Research Scientist        EN                 42000  120000   86132.000000
#                           MI                 56738  450000  136498.142857
#                           SE                 50000  144000   88859.400000
#
#                                               median
# job_title                 experience_level
# Data Analyst              EN                 59551.0
#                           EX                120000.0
#                           MI                 62000.0
#                           SE                111912.5
# Data Engineer             EN                 56388.5
#                           EX                229000.0
#                           MI                 78526.0
#                           SE                136994.0
# Data Scientist            EN                 50483.5
#                           MI                 77479.0
#                           SE                140400.0
# Machine Learning Engineer EN                 81000.0
#                           MI                 80712.5
#                           SE                135000.0
# Research Scientist        EN                 91264.0
#                           MI                 64849.0
#                           SE                 93427.0

# %% [markdown]
# # `drop_duplicates()`
#
# O Pandas oferece uma maneira fácil de remover entradas duplicadas no conjunto de dados por meio do método `drop_duplicates()`.

# %%
df.drop_duplicates()
# Out:
#       id  work_year experience_level employment_type  \
# 0      0       2020               MI              FT
# 4      4       2020               SE              FT
# 5      5       2020               EN              FT
# 7      7       2020               MI              FT
# 10    10       2020               EN              FT
# ..   ...        ...              ...             ...
# 601  601       2022               EN              FT
# 602  602       2022               SE              FT
# 603  603       2022               SE              FT
# 604  604       2022               SE              FT
# 605  605       2022               SE              FT
#
#                      job_title    salary salary_currency  salary_in_usd  \
# 0               Data Scientist     70000             EUR          79833
# 4    Machine Learning Engineer    150000             USD         150000
# 5                 Data Analyst     72000             USD          72000
# 7               Data Scientist  11000000             HUF          35735
# 10              Data Scientist     45000             EUR          51321
# ..                         ...       ...             ...            ...
# 601               Data Analyst     52000             USD          52000
# 602              Data Engineer    154000             USD         154000
# 603              Data Engineer    126000             USD         126000
# 604               Data Analyst    129000             USD         129000
# 605               Data Analyst    150000             USD         150000
#
#     employee_residence  remote_ratio company_location company_size  \
# 0                   DE             0               DE            L
# 4                   US            50               US            L
# 5                   US           100               US            L
# 7                   HU            50               HU            L
# 10                  FR             0               FR            S
# ..                 ...           ...              ...          ...
# 601                 CA             0               CA            M
# 602                 US           100               US            M
# 603                 US           100               US            M
# 604                 US             0               US            M
# 605                 US           100               US            M
#
#      montly_salary
# 0      6652.750000
# 4     12500.000000
# 5      6000.000000
# 7      2977.916667
# 10     4276.750000
# ..             ...
# 601    4333.333333
# 602   12833.333333
# 603   10500.000000
# 604   10750.000000
# 605   12500.000000
#
# [429 rows x 13 columns]

# %% [markdown]
# Como não foi especificado parâmetros, o método elimina as linhas que possuem todas as colunas com valores exatamente iguais. Nesse caso, não haviam dados duplicados.
#
# Mas, podemos especificar as colunas que queremos utilizar para fazer essa comparação. Podemos, por exemplo, remover entradas que tenham o mesmo:
#
# - `work_year`;
# - `experience_level`;
# - `employment_type`;
# - `job_title`
# - `salary_in_usd`
# - `company_location`

# %%
df = df.drop_duplicates(subset=['work_year', 'experience_level', 'employment_type', 'job_title', 'salary_in_usd', 'company_location'])
df
# Out:
#               job_title   id  work_year experience_level employment_type  \
# 0          Data Analyst  605       2022               SE              FT
# 1          Data Analyst  361       2022               SE              FT
# 2          Data Analyst  367       2022               MI              FT
# 3          Data Analyst  376       2022               SE              FT
# 4          Data Analyst  382       2022               SE              FT
# ..                  ...  ...        ...              ...             ...
# 366  Research Scientist  211       2021               MI              FT
# 367  Research Scientist  203       2021               SE              FT
# 368  Research Scientist  194       2021               SE              FT
# 369  Research Scientist  236       2021               MI              FT
# 370  Research Scientist  466       2022               SE              FT
#
#      salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0    150000             USD         150000                 US           100
# 1     61300             USD          61300                 CA           100
# 2     58000             USD          58000                 US             0
# 3    132000             USD         132000                 US             0
# 4    128875             USD         128875                 US           100
# ..      ...             ...            ...                ...           ...
# 366   48000             EUR          56738                 FR            50
# 367   50000             USD          50000                 FR           100
# 368  120500             CAD          96113                 CA            50
# 369   80000             CAD          63810                 CA           100
# 370  144000             USD         144000                 US            50
#
#     company_location company_size  montly_salary
# 0                 US            M   12500.000000
# 1                 CA            M    5108.333333
# 2                 US            S    4833.333333
# 3                 US            M   11000.000000
# 4                 US            M   10739.583333
# ..               ...          ...            ...
# 366               FR            S    4728.166667
# 367               US            S    4166.666667
# 368               CA            L    8009.416667
# 369               CA            M    5317.500000
# 370               US            L   12000.000000
#
# [371 rows x 13 columns]

# %% [markdown]
# Note que foram removidas 58 linhas com entradas duplicadas nas colunas especificadas.

# %% [markdown]
# # Pivot Tables
#
# Existe uma outra maneira de agrupar valores. Você pode criar tabelas dinâmicas indicando quais colunas deseja agrupar valores. Para isso, será utilizado o método `pivot_tables()`.
#
# Esse método recebe como parâmetros os valores (`values`) que serão agrupados e a coluna pela qual tais valores serão agrupados (`index`). Por padrão, é mostrado a média dos valores agrupados.

# %%
df.pivot_table(values='salary_in_usd', index='job_title')
# Out:
#                            salary_in_usd
# job_title
# Data Analyst                89871.837500
# Data Engineer              107724.210526
# Data Scientist              99448.573770
# Machine Learning Engineer  101165.128205
# Research Scientist         109019.500000

# %% [markdown]
# Outras medidas, no entanto, podem ser utilizadas para mostrar valores agrupados. Basta informar no parâmetro `aggfunc`. Por exemplo, se quisermos mostrar a mediana ao invés da média, basta fazer:

# %%
df.pivot_table(values='salary_in_usd', index='job_title', aggfunc=np.median)
# Out:
#                            salary_in_usd
# job_title
# Data Analyst                     90000.0
# Data Engineer                   100000.0
# Data Scientist                   91425.5
# Machine Learning Engineer        87425.0
# Research Scientist               76263.5

# %% [markdown]
# Um uso interessante de tabelas dinâmicas é utilizar duas variáveis para agrupar valores. Dessa forma, é possível fazer um cruzamento de informações.
#
# Por exemplo, podemos querer saber a média salarial por nível de experiência (semelhante ao que foi feito usando o groupby.

# %%
df.pivot_table(values='salary_in_usd', index='job_title', columns='experience_level')
# Out:
# experience_level                     EN        EX             MI  \
# job_title
# Data Analyst               53960.666667  120000.0   72188.464286
# Data Engineer              58933.500000  245500.0   83714.897959
# Data Scientist             53203.809524       NaN   81062.310345
# Machine Learning Engineer  86996.333333       NaN   74466.583333
# Research Scientist         86132.000000       NaN  136498.142857
#
# experience_level                      SE
# job_title
# Data Analyst               112656.368421
# Data Engineer              132435.265306
# Data Scientist             146833.302326
# Machine Learning Engineer  126048.555556
# Research Scientist          88859.400000

# %% [markdown]
# Os valores `Nan` acontecem porque não existem alguns valores associados às linhas ou colunas. Podemos incluir um valor para entrar como padrão caso isso aconteça.
#
# Também é possível incluir uma linha e coluna resumo.

# %%
df.pivot_table(values='salary_in_usd', index='job_title', columns='experience_level', fill_value=0, margins=True)
# Out:
# experience_level                     EN             EX             MI  \
# job_title
# Data Analyst               53960.666667  120000.000000   72188.464286
# Data Engineer              58933.500000  245500.000000   83714.897959
# Data Scientist             53203.809524       0.000000   81062.310345
# Machine Learning Engineer  86996.333333       0.000000   74466.583333
# Research Scientist         86132.000000       0.000000  136498.142857
# All                        62060.431034  203666.666667   82298.746753
#
# experience_level                      SE            All
# job_title
# Data Analyst               112656.368421   89871.837500
# Data Engineer              132435.265306  107724.210526
# Data Scientist             146833.302326   99448.573770
# Machine Learning Engineer  126048.555556  101165.128205
# Research Scientist          88859.400000  109019.500000
# All                        129393.941176  100519.636119

# %% [markdown]
# # Indexação Explícita
#
# Como já foi visto antes, cada DataFrame possui um índice para cada linha. Esse índice pode ser utilizado para fazer uma indexação explícita e obter um subconjunto de linhas do dataset.
#
# Para obter a lista de índices, basta analisar o atributo `index`.

# %%
df.index
# Out:
# Int64Index([  0,   4,   5,   7,  10,  11,  12,  14,  15,  16,
#             ...
#             585, 586, 589, 598, 600, 601, 602, 603, 604, 605],
#            dtype='int64', length=371)

# %% [markdown]
# Nesse caso, os índices são números inteiros. Mas, você pode configurar colunas para serem os índices do DataFrame. Para isso, basta usar o método `set_index` e especificar a(s) coluna(s) a ser(em) utilizada(s) como índice.
#
# Vale salientar que esse método não altera o DataFrame e você precisa atribuir a um novo objeto ou configurar o parâmetro `inplace` para que as alterações tenham efeito.

# %%
df.set_index('job_title', inplace=True)

# %% [markdown]
# Com base nisso, é possível referenciar linhas do DataFrame por meio do operador `.loc[]`. Ele aceita valores de índices para selecionar as linhas de acordo com o valor especificado para o índice.

# %%
df.loc['Data Scientist']
# Out:
#                  id  work_year experience_level employment_type    salary  \
# job_title
# Data Scientist    0       2020               MI              FT     70000
# Data Scientist    7       2020               MI              FT  11000000
# Data Scientist   10       2020               EN              FT     45000
# Data Scientist   11       2020               MI              FT   3000000
# Data Scientist   12       2020               EN              FT     35000
# ...             ...        ...              ...             ...       ...
# Data Scientist  550       2022               SE              FT    205300
# Data Scientist  552       2022               SE              FT    176000
# Data Scientist  553       2022               SE              FT    144000
# Data Scientist  570       2022               SE              FT    210000
# Data Scientist  598       2022               MI              FT    160000
#
#                salary_currency  salary_in_usd employee_residence  \
# job_title
# Data Scientist             EUR          79833                 DE
# Data Scientist             HUF          35735                 HU
# Data Scientist             EUR          51321                 FR
# Data Scientist             INR          40481                 IN
# Data Scientist             EUR          39916                 FR
# ...                        ...            ...                ...
# Data Scientist             USD         205300                 US
# Data Scientist             USD         176000                 US
# Data Scientist             USD         144000                 US
# Data Scientist             USD         210000                 US
# Data Scientist             USD         160000                 US
#
#                 remote_ratio company_location company_size  montly_salary
# job_title
# Data Scientist             0               DE            L    6652.750000
# Data Scientist            50               HU            L    2977.916667
# Data Scientist             0               FR            S    4276.750000
# Data Scientist             0               IN            L    3373.416667
# Data Scientist             0               FR            M    3326.333333
# ...                      ...              ...          ...            ...
# Data Scientist             0               US            L   17108.333333
# Data Scientist           100               US            M   14666.666667
# Data Scientist           100               US            M   12000.000000
# Data Scientist           100               US            M   17500.000000
# Data Scientist           100               US            M   13333.333333
#
# [122 rows x 12 columns]

# %% [markdown]
# Podemos ainda fazer a ordenação do DataFrame com base nos valores dos índices. Basta usarmos o método `.sort_index().

# %%
df.sort_index(inplace=True)
df.head()
# Out:
# <ipython-input-57-b9d4d5c4815d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.sort_index(inplace=True)
#                id  work_year experience_level employment_type  salary  \
# job_title
# Data Analyst  605       2022               SE              FT  150000
# Data Analyst  361       2022               SE              FT   61300
# Data Analyst  367       2022               MI              FT   58000
# Data Analyst  376       2022               SE              FT  132000
# Data Analyst  382       2022               SE              FT  128875
#
#              salary_currency  salary_in_usd employee_residence  remote_ratio  \
# job_title
# Data Analyst             USD         150000                 US           100
# Data Analyst             USD          61300                 CA           100
# Data Analyst             USD          58000                 US             0
# Data Analyst             USD         132000                 US             0
# Data Analyst             USD         128875                 US           100
#
#              company_location company_size  montly_salary
# job_title
# Data Analyst               US            M   12500.000000
# Data Analyst               CA            M    5108.333333
# Data Analyst               US            S    4833.333333
# Data Analyst               US            M   11000.000000
# Data Analyst               US            M   10739.583333

# %% [markdown]
# Você pode desfazer essa operação utilizando o método `reset_index()`. Essa reconfiguração pode ainda ser feita descartando os valores que estavam sendo utilizados como índice ou não por meio do parâmetro `drop` (o valor default é False).

# %%
df.reset_index(drop=True)
# Out:
#       id  work_year experience_level employment_type  salary salary_currency  \
# 0    605       2022               SE              FT  150000             USD
# 1    361       2022               SE              FT   61300             USD
# 2    367       2022               MI              FT   58000             USD
# 3    376       2022               SE              FT  132000             USD
# 4    382       2022               SE              FT  128875             USD
# ..   ...        ...              ...             ...     ...             ...
# 366  211       2021               MI              FT   48000             EUR
# 367  203       2021               SE              FT   50000             USD
# 368  194       2021               SE              FT  120500             CAD
# 369  236       2021               MI              FT   80000             CAD
# 370  466       2022               SE              FT  144000             USD
#
#      salary_in_usd employee_residence  remote_ratio company_location  \
# 0           150000                 US           100               US
# 1            61300                 CA           100               CA
# 2            58000                 US             0               US
# 3           132000                 US             0               US
# 4           128875                 US           100               US
# ..             ...                ...           ...              ...
# 366          56738                 FR            50               FR
# 367          50000                 FR           100               US
# 368          96113                 CA            50               CA
# 369          63810                 CA           100               CA
# 370         144000                 US            50               US
#
#     company_size  montly_salary
# 0              M   12500.000000
# 1              M    5108.333333
# 2              S    4833.333333
# 3              M   11000.000000
# 4              M   10739.583333
# ..           ...            ...
# 366            S    4728.166667
# 367            S    4166.666667
# 368            L    8009.416667
# 369            M    5317.500000
# 370            L   12000.000000
#
# [371 rows x 12 columns]

# %% [markdown]
# Como queremos os dados referentes ao cargo, vamos fazer a alteração persistir no DataFrame, deixando esse dado.

# %%
df.reset_index(drop=False, inplace=True)

# %%
df.head()
# Out:
#       job_title   id  work_year experience_level employment_type  salary  \
# 0  Data Analyst  605       2022               SE              FT  150000
# 1  Data Analyst  361       2022               SE              FT   61300
# 2  Data Analyst  367       2022               MI              FT   58000
# 3  Data Analyst  376       2022               SE              FT  132000
# 4  Data Analyst  382       2022               SE              FT  128875
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         150000                 US           100
# 1             USD          61300                 CA           100
# 2             USD          58000                 US             0
# 3             USD         132000                 US             0
# 4             USD         128875                 US           100
#
#   company_location company_size  montly_salary
# 0               US            M   12500.000000
# 1               CA            M    5108.333333
# 2               US            S    4833.333333
# 3               US            M   11000.000000
# 4               US            M   10739.583333

# %% [markdown]
# Vale dizer que esse tipo de indexação pode ser feita em múltiplos níveis, aninhando colunas. Por exemplo, podemos utilizar como índice a chave `job_title` e `experience_level`.
#
# Isso pode ser útil quando houver alguma relação de hierarquia ou dependência entre os dados. Por outro, pode ficar mais confuso gerenciar essa indexação.
#
# Para acessar os valores por meio do operador `.loc[]`, temos que passar a "chave composta" como uma tupla.
#
# _PS: Para fins de exemplificação, os resultados serão atribuídos a um outro DataFrame._

# %%
df_new = df.set_index(['job_title', 'experience_level'])

# %%
df_new.loc[('Data Scientist', 'SE')]
# Out:
# <ipython-input-62-a6bf8cc06fca>:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   df_new.loc[('Data Scientist', 'SE')]
#                                   id  work_year employment_type  salary  \
# job_title      experience_level
# Data Scientist SE                424       2022              FT   80000
#                SE                476       2022              FT  185100
#                SE                472       2022              FT  220000
#                SE                469       2022              FT  140000
#                SE                467       2022              FT  104890
#                SE                428       2022              FT  140400
#                SE                 75       2021              FT   45000
#                SE                 69       2020              FT   80000
#                SE                274       2021              FT   65720
#                SE                 58       2020              FT  120000
#                SE                550       2022              FT  205300
#                SE                552       2022              FT  176000
#                SE                553       2022              FT  144000
#                SE                570       2022              FT  210000
#                SE                 32       2020              FT   60000
#                SE                486       2022              FT  230000
#                SE                494       2022              FT  100000
#                SE                497       2022              FT  165000
#                SE                416       2022              FT  260000
#                SE                 63       2020              FT  412000
#                SE                357       2022              FT  211500
#                SE                356       2022              FT  150000
#                SE                352       2022              FT  167000
#                SE                365       2022              FT  138600
#                SE                243       2021              FT  165000
#                SE                315       2022              FT  165220
#                SE                317       2022              FT  120160
#                SE                240       2021              FT  130000
#                SE                323       2022              FT  180000
#                SE                324       2022              FT  120000
#                SE                228       2021              FT  135000
#                SE                347       2022              FT   95550
#                SE                226       2021              FT  110000
#                SE                302       2022              FT  146000
#                SE                399       2022              FT  158200
#                SE                398       2022              FT  215300
#                SE                303       2022              FT  123000
#                SE                298       2022              FT  136620
#                SE                299       2022              FT   99360
#                SE                300       2022              FT   90000
#                SE                301       2022              FT   80000
#                SE                369       2022              FT  170000
#                SE                278       2021              FT  180000
#
#                                 salary_currency  salary_in_usd  \
# job_title      experience_level
# Data Scientist SE                           USD          80000
#                SE                           USD         185100
#                SE                           USD         220000
#                SE                           USD         140000
#                SE                           USD         104890
#                SE                           USD         140400
#                SE                           EUR          53192
#                SE                           EUR          91237
#                SE                           EUR          77684
#                SE                           USD         120000
#                SE                           USD         205300
#                SE                           USD         176000
#                SE                           USD         144000
#                SE                           USD         210000
#                SE                           EUR          68428
#                SE                           USD         230000
#                SE                           USD         100000
#                SE                           USD         165000
#                SE                           USD         260000
#                SE                           USD         412000
#                SE                           USD         211500
#                SE                           USD         150000
#                SE                           USD         167000
#                SE                           USD         138600
#                SE                           USD         165000
#                SE                           USD         165220
#                SE                           USD         120160
#                SE                           CAD         103691
#                SE                           USD         180000
#                SE                           USD         120000
#                SE                           USD         135000
#                SE                           USD          95550
#                SE                           CAD          87738
#                SE                           USD         146000
#                SE                           USD         158200
#                SE                           USD         215300
#                SE                           USD         123000
#                SE                           USD         136620
#                SE                           USD          99360
#                SE                           GBP         117789
#                SE                           GBP         104702
#                SE                           USD         170000
#                SE                           TRY          20171
#
#                                 employee_residence  remote_ratio  \
# job_title      experience_level
# Data Scientist SE                               US             0
#                SE                               US           100
#                SE                               US           100
#                SE                               US           100
#                SE                               US           100
#                SE                               US             0
#                SE                               FR            50
#                SE                               AT             0
#                SE                               FR            50
#                SE                               US            50
#                SE                               US             0
#                SE                               US           100
#                SE                               US           100
#                SE                               US           100
#                SE                               GR           100
#                SE                               US           100
#                SE                               BR           100
#                SE                               US           100
#                SE                               US           100
#                SE                               US           100
#                SE                               US           100
#                SE                               US             0
#                SE                               US           100
#                SE                               US           100
#                SE                               US           100
#                SE                               US           100
#                SE                               US           100
#                SE                               CA           100
#                SE                               US             0
#                SE                               US             0
#                SE                               US             0
#                SE                               US             0
#                SE                               CA           100
#                SE                               US           100
#                SE                               US           100
#                SE                               US           100
#                SE                               US           100
#                SE                               US           100
#                SE                               US           100
#                SE                               GB             0
#                SE                               GB             0
#                SE                               US           100
#                SE                               TR            50
#
#                                 company_location company_size  montly_salary
# job_title      experience_level
# Data Scientist SE                             US            M    6666.666667
#                SE                             US            M   15425.000000
#                SE                             US            M   18333.333333
#                SE                             US            M   11666.666667
#                SE                             US            M    8740.833333
#                SE                             US            L   11700.000000
#                SE                             FR            L    4432.666667
#                SE                             AT            S    7603.083333
#                SE                             FR            M    6473.666667
#                SE                             US            L   10000.000000
#                SE                             US            L   17108.333333
#                SE                             US            M   14666.666667
#                SE                             US            M   12000.000000
#                SE                             US            M   17500.000000
#                SE                             US            L    5702.333333
#                SE                             US            M   19166.666667
#                SE                             US            M    8333.333333
#                SE                             US            M   13750.000000
#                SE                             US            M   21666.666667
#                SE                             US            L   34333.333333
#                SE                             US            M   17625.000000
#                SE                             US            M   12500.000000
#                SE                             US            M   13916.666667
#                SE                             US            M   11550.000000
#                SE                             US            L   13750.000000
#                SE                             US            M   13768.333333
#                SE                             US            M   10013.333333
#                SE                             CA            L    8640.916667
#                SE                             US            L   15000.000000
#                SE                             US            L   10000.000000
#                SE                             US            L   11250.000000
#                SE                             US            M    7962.500000
#                SE                             CA            S    7311.500000
#                SE                             US            M   12166.666667
#                SE                             US            L   13183.333333
#                SE                             US            L   17941.666667
#                SE                             US            M   10250.000000
#                SE                             US            M   11385.000000
#                SE                             US            M    8280.000000
#                SE                             GB            M    9815.750000
#                SE                             GB            M    8725.166667
#                SE                             US            M   14166.666667
#                SE                             TR            L    1680.916667

# %% [markdown]
# Você pode passar mais de uma combinação para selecionar linhas.

# %%
jobs_exp = [('Data Analyst', 'MI'), ('Data Scientist', 'SE')]
df_new.loc[jobs_exp]
# Out:
#                                   id  work_year employment_type  salary  \
# job_title      experience_level
# Data Analyst   MI                367       2022              FT   58000
#                MI                408       2022              FT   40000
#                MI                429       2022              FT   30000
#                MI                430       2022              FT   40000
#                MI                431       2022              FT   30000
# ...                              ...        ...             ...     ...
# Data Scientist SE                299       2022              FT   99360
#                SE                300       2022              FT   90000
#                SE                301       2022              FT   80000
#                SE                369       2022              FT  170000
#                SE                278       2021              FT  180000
#
#                                 salary_currency  salary_in_usd  \
# job_title      experience_level
# Data Analyst   MI                           USD          58000
#                MI                           GBP          52351
#                MI                           GBP          39263
#                MI                           EUR          43966
#                MI                           EUR          32974
# ...                                         ...            ...
# Data Scientist SE                           USD          99360
#                SE                           GBP         117789
#                SE                           GBP         104702
#                SE                           USD         170000
#                SE                           TRY          20171
#
#                                 employee_residence  remote_ratio  \
# job_title      experience_level
# Data Analyst   MI                               US             0
#                MI                               GB           100
#                MI                               GB           100
#                MI                               ES           100
#                MI                               ES           100
# ...                                            ...           ...
# Data Scientist SE                               US           100
#                SE                               GB             0
#                SE                               GB             0
#                SE                               US           100
#                SE                               TR            50
#
#                                 company_location company_size  montly_salary
# job_title      experience_level
# Data Analyst   MI                             US            S    4833.333333
#                MI                             GB            M    4362.583333
#                MI                             GB            M    3271.916667
#                MI                             ES            M    3663.833333
#                MI                             ES            M    2747.833333
# ...                                          ...          ...            ...
# Data Scientist SE                             US            M    8280.000000
#                SE                             GB            M    9815.750000
#                SE                             GB            M    8725.166667
#                SE                             US            M   14166.666667
#                SE                             TR            L    1680.916667
#
# [71 rows x 11 columns]

# %% [markdown]
# ## Fatiamento
#
# De forma semelhantes às listas, é possível fazer o fatiamento de um DataFrame para obter uma parte dele. A primeira maneira de fazer isso é utilizando o operador `.loc[]`. Basta passar o valor inicial do índice e o valor final (nesse caso, é incluído dentro da seleção).

# %%
df.loc[0:10]
# Out:
#        job_title   id  work_year experience_level employment_type  salary  \
# 0   Data Analyst  605       2022               SE              FT  150000
# 1   Data Analyst  361       2022               SE              FT   61300
# 2   Data Analyst  367       2022               MI              FT   58000
# 3   Data Analyst  376       2022               SE              FT  132000
# 4   Data Analyst  382       2022               SE              FT  128875
# 5   Data Analyst  383       2022               SE              FT   93700
# 6   Data Analyst  387       2022               SE              FT  164000
# 7   Data Analyst  172       2021               EN              FT   60000
# 8   Data Analyst  402       2022               SE              FT  115934
# 9   Data Analyst  403       2022               SE              FT   81666
# 10  Data Analyst  408       2022               MI              FT   40000
#
#    salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0              USD         150000                 US           100
# 1              USD          61300                 CA           100
# 2              USD          58000                 US             0
# 3              USD         132000                 US             0
# 4              USD         128875                 US           100
# 5              USD          93700                 US           100
# 6              USD         164000                 US             0
# 7              USD          60000                 US           100
# 8              USD         115934                 US             0
# 9              USD          81666                 US             0
# 10             GBP          52351                 GB           100
#
#    company_location company_size  montly_salary
# 0                US            M   12500.000000
# 1                CA            M    5108.333333
# 2                US            S    4833.333333
# 3                US            M   11000.000000
# 4                US            M   10739.583333
# 5                US            M    7808.333333
# 6                US            M   13666.666667
# 7                US            S    5000.000000
# 8                US            M    9661.166667
# 9                US            M    6805.500000
# 10               GB            M    4362.583333

# %% [markdown]
# Veja que usamos o valor do índice para fazer o fatiamento. Se o índice fosse outro, poderíamos adotar a mesma abordagem.
#
# Vamos novamente considerar que o `job_title` é índice e fazer uma fatiamento com base nisso.

# %%
df_new = df.set_index('job_title')
df_new.loc['Data Analyst':'Data Scientist']
# Out:
#                  id  work_year experience_level employment_type  salary  \
# job_title
# Data Analyst    605       2022               SE              FT  150000
# Data Analyst    361       2022               SE              FT   61300
# Data Analyst    367       2022               MI              FT   58000
# Data Analyst    376       2022               SE              FT  132000
# Data Analyst    382       2022               SE              FT  128875
# ...             ...        ...              ...             ...     ...
# Data Scientist  300       2022               SE              FT   90000
# Data Scientist  301       2022               SE              FT   80000
# Data Scientist  369       2022               SE              FT  170000
# Data Scientist  287       2021               MI              FT  109000
# Data Scientist  278       2021               SE              FT  180000
#
#                salary_currency  salary_in_usd employee_residence  \
# job_title
# Data Analyst               USD         150000                 US
# Data Analyst               USD          61300                 CA
# Data Analyst               USD          58000                 US
# Data Analyst               USD         132000                 US
# Data Analyst               USD         128875                 US
# ...                        ...            ...                ...
# Data Scientist             GBP         117789                 GB
# Data Scientist             GBP         104702                 GB
# Data Scientist             USD         170000                 US
# Data Scientist             USD         109000                 US
# Data Scientist             TRY          20171                 TR
#
#                 remote_ratio company_location company_size  montly_salary
# job_title
# Data Analyst             100               US            M   12500.000000
# Data Analyst             100               CA            M    5108.333333
# Data Analyst               0               US            S    4833.333333
# Data Analyst               0               US            M   11000.000000
# Data Analyst             100               US            M   10739.583333
# ...                      ...              ...          ...            ...
# Data Scientist             0               GB            M    9815.750000
# Data Scientist             0               GB            M    8725.166667
# Data Scientist           100               US            M   14166.666667
# Data Scientist            50               US            L    9083.333333
# Data Scientist            50               TR            L    1680.916667
#
# [316 rows x 12 columns]

# %% [markdown]
# É possível também fazer o fatiamento de colunas passando um outro intervalo como segundo parâmetro do operador `.loc[]`.

# %%
df_new.loc['Data Analyst':'Data Scientist', 'work_year':'salary']
# Out:
#                 work_year experience_level employment_type  salary
# job_title
# Data Analyst         2022               SE              FT  150000
# Data Analyst         2022               SE              FT   61300
# Data Analyst         2022               MI              FT   58000
# Data Analyst         2022               SE              FT  132000
# Data Analyst         2022               SE              FT  128875
# ...                   ...              ...             ...     ...
# Data Scientist       2022               SE              FT   90000
# Data Scientist       2022               SE              FT   80000
# Data Scientist       2022               SE              FT  170000
# Data Scientist       2021               MI              FT  109000
# Data Scientist       2021               SE              FT  180000
#
# [316 rows x 4 columns]

# %% [markdown]
# A outra maneira de fatiar o DataFrame é utilizar o operador `.iloc[]`. A diferença principal é que você não se refere necessariamente ao índice e deve especificar as posições de linhas e colunas do DataFrame.
#
# O funcionamento é ainda mais parecido com o fatiamento de listas. Aqui, o primeiro parâmetro seleciona as linhas e o segundo, as colunas. Se trabalharmos como o operador `:`, o último valor não é incluído na seleção.
#
# Então, para obter as 10 primeiras linhas das quinta e sexta colunas, devemos fazer:

# %%
df_new.iloc[:10, 4:6]
# Out:
#               salary salary_currency
# job_title
# Data Analyst  150000             USD
# Data Analyst   61300             USD
# Data Analyst   58000             USD
# Data Analyst  132000             USD
# Data Analyst  128875             USD
# Data Analyst   93700             USD
# Data Analyst  164000             USD
# Data Analyst   60000             USD
# Data Analyst  115934             USD
# Data Analyst   81666             USD

# %% [markdown]
# # Visualização de Dados
#
# Como mencioando antes, o Pandas tem como uma das bases o `matplotlib`, uma biblioteca para visualizção de dados.
#
# Isso significa que mostrar os dados de um DataFrame em formato de gráfico é bastante simples. Vamos verificar algumas formas de fazer isso.

# %% [markdown]
# ## Histograma

# %%
df['salary_in_usd'].hist()
plt.show()

# %% [markdown]
# Você pode ajustar a quantidade de intervalos em que os dados serão divididos usando o parâmetro `bins`.

# %%
df['salary_in_usd'].hist(bins = 5)
plt.show()

# %% [markdown]
# ## Barras
#
# Para escolher um tipo de gráfico, é possível utilizar o método `plot` e parâmetro `kind`.
#
# De fato, todos os tipos de gráfico podem ser feitos utilizando o método `.plot()`. A lista completa de gráficos possíveis pode ser vista [aqui](https://pandas.pydata.org/docs/user_guide/visualization.html) e incluem os seguintes tipos:
#
# - `bar` ou `barh` para gráficos de barra;
# - `hist` para histogramas;
# - `box` para boxplot;
# - `kde` ou `density` para densidade;
# - `area` para gráficos de área;
# - `scatter` para dispersão;
# - `hexbin` para mapas exagonais;
# - `pie` para gráficos de pizza.

# %%
avg_salary = df.groupby('job_title')['salary_in_usd'].mean()
avg_salary.plot(kind='bar')
plt.show()

# %% [markdown]
# ## Pizza

# %%
df['job_title'].value_counts().plot(kind='pie')
plt.show()

# %% [markdown]
# Podemos adicionar outros elementos no gráfico, como título e legenda.

# %%
df['job_title'].value_counts().index
# Out:
# Index(['Data Scientist', 'Data Engineer', 'Data Analyst',
#        'Machine Learning Engineer', 'Research Scientist'],
#       dtype='object')

# %%
df['job_title'].value_counts().plot(kind='pie', title='Média Salarial')
plt.legend(df['job_title'].value_counts().index, loc='upper center', fontsize='small', ncols=5)
plt.show()

# %% [markdown]
# # Valores faltosos
#
# Uma das tarefas mais importantes na análise de dados consiste em verificar se existem valores faltando no conjunto de dados.
#
# Para exemplificar um conjunto com dados faltosos, vamos fazer uma nova importação da mesma base, mas onde alguns valores da coluna 'salary_in_usd' foram aleatoriamente removidos.

# %%
# !wget 'https://raw.githubusercontent.com/danielsabino/IMD1101-AM-2024.1/pandas/ds_salaries2.csv'
# Out:
# --2024-03-20 00:02:31--  https://raw.githubusercontent.com/danielsabino/IMD1101-AM-2024.1/pandas/ds_salaries2.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 37499 (37K) [text/plain]
# Saving to: ‘ds_salaries2.csv’
#
# ds_salaries2.csv    100%[===================>]  36.62K  --.-KB/s    in 0.003s
#
# 2024-03-20 00:02:31 (10.8 MB/s) - ‘ds_salaries2.csv’ saved [37499/37499]

# %%
df2 = pd.read_csv('ds_salaries2.csv', sep=';')

# %% [markdown]
# ## `.isna()`
#
# Por meio do método `.isna()` conseguimos verificar para todos os campos da base se o dado está presente ou não.

# %%
df2.isna()
# Out:
#      Unnamed: 0  work_year  experience_level  employment_type  job_title  \
# 0         False      False             False            False      False
# 1         False      False             False            False      False
# 2         False      False             False            False      False
# 3         False      False             False            False      False
# 4         False      False             False            False      False
# ..          ...        ...               ...              ...        ...
# 602       False      False             False            False      False
# 603       False      False             False            False      False
# 604       False      False             False            False      False
# 605       False      False             False            False      False
# 606       False      False             False            False      False
#
#      salary  salary_currency  salary_in_usd  employee_residence  remote_ratio  \
# 0     False            False          False               False         False
# 1     False            False          False               False         False
# 2     False            False          False               False         False
# 3     False            False          False               False         False
# 4     False            False          False               False         False
# ..      ...              ...            ...                 ...           ...
# 602   False            False          False               False         False
# 603   False            False          False               False         False
# 604   False            False          False               False         False
# 605   False            False          False               False         False
# 606   False            False          False               False         False
#
#      company_location  company_size
# 0               False         False
# 1               False         False
# 2               False         False
# 3               False         False
# 4               False         False
# ..                ...           ...
# 602             False         False
# 603             False         False
# 604             False         False
# 605             False         False
# 606             False         False
#
# [607 rows x 12 columns]

# %% [markdown]
# No entato, quando a base se torna maior, essa visualização não é muito últil. Podemos usar o método `.any()` para avaliar se existe algum dados faltoso em cada coluna do DataFrame.

# %%
df2.isna().any()
# Out:
# Unnamed: 0            False
# work_year             False
# experience_level      False
# employment_type       False
# job_title             False
# salary                False
# salary_currency       False
# salary_in_usd          True
# employee_residence    False
# remote_ratio          False
# company_location      False
# company_size          False
# dtype: bool

# %% [markdown]
# Podemos ainda saber a quantidade de valores faltosos nas colunas por meio do método `.sum()`.

# %%
df2.isna().sum()
# Out:
# Unnamed: 0             0
# work_year              0
# experience_level       0
# employment_type        0
# job_title              0
# salary                 0
# salary_currency        0
# salary_in_usd         12
# employee_residence     0
# remote_ratio           0
# company_location       0
# company_size           0
# dtype: int64

# %% [markdown]
# Esse é um dado que pode ser visualizado.

# %%
df2.isna().sum().plot(kind='bar')
plt.show()

# %% [markdown]
# Para tratar esse problema, podemos usar algumas abordagens. As duas mais comuns são: remover as linhas que possuem algum dado faltando ou preencher os campos que estão com valores faltando.

# %% [markdown]
# ## `.dropna()`
#
# Esse método simplesmente remove todas as linhas que possme valores faltando. Se não for especificado parâmetros, se alguma coluna tiver valores faltando, a linha é removida.

# %%
df2.dropna()
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR        79833.0
# 1    Machine Learning Scientist  260000             USD       260000.0
# 2             Big Data Engineer   85000             GBP       109024.0
# 3          Product Data Analyst   20000             USD        20000.0
# 4     Machine Learning Engineer  150000             USD       150000.0
# ..                          ...     ...             ...            ...
# 602               Data Engineer  154000             USD       154000.0
# 603               Data Engineer  126000             USD       126000.0
# 604                Data Analyst  129000             USD       129000.0
# 605                Data Analyst  150000             USD       150000.0
# 606                AI Scientist  200000             USD       200000.0
#
#     employee_residence  remote_ratio company_location company_size
# 0                   DE             0               DE            L
# 1                   JP             0               JP            S
# 2                   GB            50               GB            M
# 3                   HN             0               HN            S
# 4                   US            50               US            L
# ..                 ...           ...              ...          ...
# 602                 US           100               US            M
# 603                 US           100               US            M
# 604                 US             0               US            M
# 605                 US           100               US            M
# 606                 IN           100               US            L
#
# [595 rows x 12 columns]

# %% [markdown]
# Mas, essa verificação pode ser feita considerando alguma(s) coluna(s) em específico.

# %%
df2.dropna(subset=['work_year'])
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR        79833.0
# 1    Machine Learning Scientist  260000             USD       260000.0
# 2             Big Data Engineer   85000             GBP       109024.0
# 3          Product Data Analyst   20000             USD        20000.0
# 4     Machine Learning Engineer  150000             USD       150000.0
# ..                          ...     ...             ...            ...
# 602               Data Engineer  154000             USD       154000.0
# 603               Data Engineer  126000             USD       126000.0
# 604                Data Analyst  129000             USD       129000.0
# 605                Data Analyst  150000             USD       150000.0
# 606                AI Scientist  200000             USD       200000.0
#
#     employee_residence  remote_ratio company_location company_size
# 0                   DE             0               DE            L
# 1                   JP             0               JP            S
# 2                   GB            50               GB            M
# 3                   HN             0               HN            S
# 4                   US            50               US            L
# ..                 ...           ...              ...          ...
# 602                 US           100               US            M
# 603                 US           100               US            M
# 604                 US             0               US            M
# 605                 US           100               US            M
# 606                 IN           100               US            L
#
# [607 rows x 12 columns]

# %% [markdown]
# Nesse caso, como a coluna `work_year` possui todos valores para todas as linhas, nenhuma foi removida.

# %% [markdown]
# ## `.fillna()`
#
# Uma outra forma de contornar o problema de dados faltosos é atribuir valores para preencher o campo. O método `.fillna` insere um valor pré-determinado toda vez que encontra um campo faltando dado. Podemos preencher, por exemplo, o campo com o valor 0.

# %%
df2.fillna(0)
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR        79833.0
# 1    Machine Learning Scientist  260000             USD       260000.0
# 2             Big Data Engineer   85000             GBP       109024.0
# 3          Product Data Analyst   20000             USD        20000.0
# 4     Machine Learning Engineer  150000             USD       150000.0
# ..                          ...     ...             ...            ...
# 602               Data Engineer  154000             USD       154000.0
# 603               Data Engineer  126000             USD       126000.0
# 604                Data Analyst  129000             USD       129000.0
# 605                Data Analyst  150000             USD       150000.0
# 606                AI Scientist  200000             USD       200000.0
#
#     employee_residence  remote_ratio company_location company_size
# 0                   DE             0               DE            L
# 1                   JP             0               JP            S
# 2                   GB            50               GB            M
# 3                   HN             0               HN            S
# 4                   US            50               US            L
# ..                 ...           ...              ...          ...
# 602                 US           100               US            M
# 603                 US           100               US            M
# 604                 US             0               US            M
# 605                 US           100               US            M
# 606                 IN           100               US            L
#
# [607 rows x 12 columns]

# %% [markdown]
# Ou podemos preencher com um valor central, como a mediana.

# %%
med = np.median(df2['salary_in_usd'])
df2['salary_in_usd'].fillna('salary_in_usd', inplace=True)

# %% [markdown]
# Podemos verificar que não existem mais colunas com valores faltosos.

# %%
df2.isna().sum()
# Out:
# Unnamed: 0            0
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64
